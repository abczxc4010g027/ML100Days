# %% [markdown]
# # 作業

# %% [markdown]
# ### 1. 根據題目給的 DataFrame 完成下列操作：
#
# ```
# - 計算每個不同種類 animal 的 age 的平均數
# - 計算每個不同種類 animal 的 age 的平均數
# - 將資料依照 Age 欄位由小到大排序，再依照 visits 欄位由大到小排序
# - 將 priority 欄位中的 yes 和 no 字串，換成是布林值 的 True 和 False
# ```

# %%
### 1. 根據題目給的 DataFrame 完成下列操作：

```
- 計算每個不同種類 animal 的 age 的平均數
- 計算每個不同種類 animal 的 age 的平均數
- 將資料依照 Age 欄位由小到大排序，再依照 visits 欄位由大到小排序
- 將 priority 欄位中的 yes 和 no 字串，換成是布林值 的 True 和 False
```

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
    'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
    'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']
}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#計算每個不同種類 animal 的 age 的平均數
df.groupby(['animal'])['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %%
#將資料依照 Age 欄位由小到大排序，再依照 visits 欄位由大到小排序
df.sort_values('age')
# Out:
#   animal  age  visits priority
# c  snake  0.5       2       no
# f    cat  2.0       3       no
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# g  snake  4.5       1       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
#將 priority 欄位中的 yes 和 no 字串，換成是布林值 的 True 和 False
df.replace(['yes', 'np'], ['True', 'False'])
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %%
df['priority'] = df['priority'].map({'yes': True, 'no':False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# ### 2. 一個包含兩個欄位的 DataFrame，將每個數字減去
#
# * 1) 該欄位的平均數
# * 2) 該筆資料平均數

# %%
np.random.seed(1)
df = pd.DataFrame(np.random.random(size=(5, 3)))
df
# Out:
#           0         1         2
# 0  0.417022  0.720324  0.000114
# 1  0.302333  0.146756  0.092339
# 2  0.186260  0.345561  0.396767
# 3  0.538817  0.419195  0.685220
# 4  0.204452  0.878117  0.027388

# %%
df - df.mean(axis = 0)
# Out:
#           0         1         2
# 0  0.087245  0.218334 -0.240251
# 1 -0.027444 -0.355235 -0.148027
# 2 -0.143517 -0.156430  0.156402
# 3  0.209040 -0.082796  0.444854
# 4 -0.125325  0.376127 -0.212978

# %%
df.sub(df.mean(axis = 0), axis = 1)
# Out:
#           0         1         2
# 0  0.087245  0.218334 -0.240251
# 1 -0.027444 -0.355235 -0.148027
# 2 -0.143517 -0.156430  0.156402
# 3  0.209040 -0.082796  0.444854
# 4 -0.125325  0.376127 -0.212978

# %% [markdown]
# ### 3. 承上題，請問：
#
# 1) 哪一比的資料總合最小
# 2) 哪一欄位的資料總合最小

# %%
#哪一比的資料總合最小
df.sum(axis = 1).idxmin()
# Out:
# 1

# %%
df.sum(axis = 0).idxmin()
# Out:
# 2
